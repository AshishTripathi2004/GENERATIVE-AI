# %%
#if elif else
age =  int(input("Enter age:"))
if(age>90):
    print("You are over age...")
elif(age<18):
    print("Oops...you are still under age...")
else:
    print("You are allowed to vote in the elections...")
# Out:
# Oops...you are still under age...

# %%
##nested conditionals
##checking negative, odd positive and odd negative

n = int(input("Enter number:"))

if(n<0):
    print("It is negative")
else:
    print("It is positive")
    if(n%2==0):
        print("It is even")
    else:
        print("It is odd")
# Out:
# It is negative

# %%
##determine if a year is a leap year

year = int(input("Enter year:"))

if((year%400 == 0) or (year%4 !=0 and year%100!=0)):
    print("It is a non-leap year")
else:
    print("It is a leap year")
# Out:
# It is a leap year

# %%
##determine ticket price based on age and whether a student or not

age = int(input("Enter age:"))
is_stud = input("Are you a student(y/n):").lower()

if age<5:
    print("Ticket Free...")
elif age<=12:
    print("Ticket is 100rs")
elif age<=17:
    print("Ticket is 200rs")
elif age<=64:
    if is_stud == "y":
        print("Ticket is 200rs")
    else:
        print("Ticket is 350rs")
else:
    if is_stud == "y":
        print("Ticket is 300rs")
    else:
        print("Ticket is 450rs")
# Out:
# Ticket is 350rs
