# %%
import os

# %%
## get current working directory
## list all the availaible directories
print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\ashis\PYTHON_LEARNING\04_MODULES_PACKAGES
# ['01_modules.ipynb', '02_modules.ipynb', 'package']

# %%
## make a new directory in the current directory location
os.mkdir("new_directoty")

# %%
##get all environment variables
##returns a dictionary consisiting of key value pairs
##stores paths,usernames,temp,etc
print(os.environ)
print(os.environ.get("USERNAME"))
print(os.environ.get("PATH"))
print(os.environ.get("USERPROFILE"))
print(os.environ.get("SYSTEMROOT"))
# Out:
# environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\ashis\\AppData\\Roaming', 'ASL.LOG': 'Destination=file', 'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey', 'CHOCOLATEYLASTPATHUPDATE': '133722588893639918', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_24928_TDABIOSHKLINUVXZ', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'ASHISH', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'CONDA_DEFAULT_ENV': 'c:\\Users\\ashis\\PYTHON_LEARNING\\venv', 'CONDA_EXE': 'C:\\Users\\ashis\\anaconda3\\Scripts\\conda.exe', 'CONDA_PREFIX': 'c:\\Users\\ashis\\PYTHON_LEARNING\\venv', 'CONDA_PROMPT_MODIFIER': '(c:\\Users\\ashis\\PYTHON_LEARNING\\venv) ', 'CONDA_PYTHON_EXE': 'C:\\Users\\ashis\\anaconda3\\python.exe', 'CONDA_ROOT': 'C:\\Users\\ashis\\anaconda3', 'CONDA_SHLVL': '1', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\Driver
# ...

# %%
## check if file exists
check = os.path.exists(r"C:\Users\ashis\PYTHON_LEARNING\04_MODULES_PACKAGES\01_modules.ipynb")
print(check)
check = os.path.exists(r"C:\Users\ashis\HON_LEARNING\04_MODULES_PACKAGES\01_modules.ipynb")
print(check)
# Out:
# True
# False

# %%
##get the size of the file in bytes
print(os.path.getsize(r"C:\Users\ashis\PYTHON_LEARNING\04_MODULES_PACKAGES\01_modules.ipynb"))
# Out:
# 3721

# %%
##system commands
print(os.system("dir"))
print(os.getpid())
# Out:
# 0
# 27292
