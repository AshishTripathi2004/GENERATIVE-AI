# %%
import os
print(os.getcwd())
# Out:
# c:\Users\ashis\PYTHON_LEARNING\05_FILE_HANDLING

# %%
print(os.listdir("."))##. - current working location
print(os.listdir(".."))## .. - just one step outside
# Out:
# ['01_file_operations.ipynb', '02_file_paths.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'read-write.txt', 'source.txt']
# ['.git', '01_BASICS', '02_DATA_STRUCTURES', '03_FUNCTIONS', '04_MODULES_PACKAGES', '05_FILE_HANDLING', 'readme.md', 'requirements.txt', 'venv']

# %%
new_directory = "package"
os.mkdir(new_directory)

# %%
## joining paths
new_dir = "folder"
new_file = "file.txt"
full_path = os.path.join(new_dir,new_file)
print(full_path)
full_path = os.path.join(os.getcwd(),new_dir,new_file)
print(full_path)
# Out:
# folder\file.txt
# c:\Users\ashis\PYTHON_LEARNING\05_FILE_HANDLING\folder\file.txt

# %%
## check whether path exists
path = "example.txt"
print(os.path.exists(path))
path = "exampl.txt"
print(os.path.exists(path))
# Out:
# True
# False

# %%
##check whether a file is a list or directory
path = "package"
if os.path.isfile(path):
    print("FILE")
elif os.path.isdir(path):
    print("DIRECTORY")
else:
    print("NONE OF THEM")
# Out:
# DIRECTORY

# %%
## getting the abosulte path i.e, complete path
path = "example.txt"
print(os.path.abspath(path))
# Out:
# c:\Users\ashis\PYTHON_LEARNING\05_FILE_HANDLING\example.txt
