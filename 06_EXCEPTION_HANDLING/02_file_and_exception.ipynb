# %%
try:
    file = open("this.txt","r")
    contents = file.read()
    print(contents)
except FileNotFoundError as er:
    print("the file does not exists...")
except Exception as er:
    print("oops...some error has occurred....")
finally:
    if 'file' in locals() and not file.closed():
        file.close()
# Out:
# the file does not exists...
