# %%
### CLASSES
### blueprint for creating objects
### attributes and methods

class Dog:
    ## define a constructor
    def __init__(self,name,age):
        ##self represents the current instance of the class
        self.name=name
        self.age=age
    
    def bark(self):
        print(f"{self.name} says woof woof")

dog1 = Dog("Coco",4)
dog1.bark()
dir(Dog)
dir(dog1)
# Out:
# Coco says woof woof
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'bark',
#  'name']

# %%
### Modelling a bank account

class BankAccount:

    def __init__(self,owner,balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self,amount):
        self.balance+=amount
        print("Amount has been deposited")
        print(f"Current Balance is Rs.{self.balance}")

    def withdraw(self, amount):
        if(self.balance < amount):
            print("Insufficient funds")
            return
        self.balance-=amount
        print("Amount withdrawn from account")
        print(f"Remaining Balance is Rs.{self.balance}")
    
    def checkBalance(self):
        print(f"Current balance is {self.balance}")

# %%
## create a new bank account
acc1 = BankAccount("Ashish",5000)
acc1.deposit(1000)
acc1.withdraw(200)
acc1.checkBalance()
acc1.withdraw(10000)
# Out:
# Amount has been deposited
# Current Balance is Rs.6000
# Amount withdrawn from account
# Remaining Balance is Rs.5800
# Current balance is 5800
# Insufficient funds
